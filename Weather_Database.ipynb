# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2e942fc4057d84141941afe2f4fd523c

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_weather_description = city_weather["weather"][0]['description']   
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | pangnirtung
# Processing Record 3 of Set 1 | westport
# Processing Record 4 of Set 1 | isiro
# Processing Record 5 of Set 1 | porto velho
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 1 | labuhan
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | venado
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | salalah
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | torres
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | san luis rio colorado
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | gubkinskiy
# Processing Record 26 of Set 1 | naze
# Processing Record 27 of Set 1 | bardiyah
# Processing Record 28 of Set 1 | lata
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | balgazyn
# Processing Record 31 of Set 1 | broome
# Processing Record 32 of Set 1 | fukue
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | hambantota
# Processing Record 36 of Set 1 | veraval
# Processing Record 37 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 1 | dzilam gonzalez
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | saint-joseph
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | carauari
# Processing Record 45 of Set 1 | turan
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | goma
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | luganville
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | manga
# Processing Record 6 of Set 2 | yumen
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | ellisras
# Processing Record 11 of Set 2 | kidal
# Processing Record 12 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | linares
# Processing Record 27 of Set 2 | pacaembu
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | tayu
# Processing Record 30 of Set 2 | hami
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | poum
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | visnes
# Processing Record 35 of Set 2 | fulton
# Processing Record 36 of Set 2 | gao
# Processing Record 37 of Set 2 | aykhal
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 2 | vila franca do campo
# Processing Record 42 of Set 2 | asau
# Processing Record 43 of Set 2 | verkhnevilyuysk
# Processing Record 44 of Set 2 | poroshkovo
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | ihosy
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | sorkjosen
# Processing Record 49 of Set 2 | zarubino
# Processing Record 50 of Set 2 | great yarmouth
# Processing Record 1 of Set 3 | kosh-agach
# Processing Record 2 of Set 3 | artyom
# Processing Record 3 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 3 | walvis bay
# Processing Record 5 of Set 3 | kuytun
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | luderitz
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | marzuq
# Processing Record 11 of Set 3 | flinders
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | murray bridge
# Processing Record 15 of Set 3 | grand-lahou
# Processing Record 16 of Set 3 | mount gambier
# Processing Record 17 of Set 3 | buchanan
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | san ramon
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | vila velha
# Processing Record 25 of Set 3 | djibo
# Processing Record 26 of Set 3 | verkhnyaya inta
# Processing Record 27 of Set 3 | balkanabat
# Processing Record 28 of Set 3 | poya
# Processing Record 29 of Set 3 | malmesbury
# Processing Record 30 of Set 3 | la ronge
# Processing Record 31 of Set 3 | tura
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | omagh
# Processing Record 36 of Set 3 | la palma
# Processing Record 37 of Set 3 | tigil
# Processing Record 38 of Set 3 | gravdal
# Processing Record 39 of Set 3 | qasigiannguit
# Processing Record 40 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | lasa
# Processing Record 44 of Set 3 | byron bay
# Processing Record 45 of Set 3 | mokhsogollokh
# Processing Record 46 of Set 3 | meulaboh
# Processing Record 47 of Set 3 | sayyan
# Processing Record 48 of Set 3 | boende
# Processing Record 49 of Set 3 | bontang
# Processing Record 50 of Set 3 | pevek
# Processing Record 1 of Set 4 | guhagar
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 4 | ambilobe
# Processing Record 5 of Set 4 | hunchun
# Processing Record 6 of Set 4 | fernie
# Processing Record 7 of Set 4 | merrill
# Processing Record 8 of Set 4 | kaliua
# Processing Record 9 of Set 4 | san cristobal
# Processing Record 10 of Set 4 | sao desiderio
# Processing Record 11 of Set 4 | port hardy
# Processing Record 12 of Set 4 | bonavista
# Processing Record 13 of Set 4 | golpayegan
# Processing Record 14 of Set 4 | belaya gora
# Processing Record 15 of Set 4 | kudahuvadhoo
# Processing Record 16 of Set 4 | ewa beach
# Processing Record 17 of Set 4 | slatinany
# Processing Record 18 of Set 4 | tari
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | cuenca
# Processing Record 21 of Set 4 | avarua
# Processing Record 22 of Set 4 | iskateley
# Processing Record 23 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 4 | sokoni
# Processing Record 25 of Set 4 | sergeyevka
# Processing Record 26 of Set 4 | glens falls
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | kavaratti
# Processing Record 29 of Set 4 | jacksonville
# Processing Record 30 of Set 4 | kahului
# Processing Record 31 of Set 4 | puno
# Processing Record 32 of Set 4 | sambava
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | pitkyaranta
# Processing Record 35 of Set 4 | yulara
# Processing Record 36 of Set 4 | beidao
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | henties bay
# Processing Record 39 of Set 4 | snyder
# Processing Record 40 of Set 4 | boyolangu
# Processing Record 41 of Set 4 | mopti
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | middelburg
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | san carlos
# Processing Record 48 of Set 4 | san quintin
# Processing Record 49 of Set 4 | meybod
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | conceicao da barra
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | ust-tsilma
# Processing Record 4 of Set 5 | mirador
# Processing Record 5 of Set 5 | chabahar
# Processing Record 6 of Set 5 | holme
# Processing Record 7 of Set 5 | bethel
# Processing Record 8 of Set 5 | touros
# Processing Record 9 of Set 5 | kattivakkam
# Processing Record 10 of Set 5 | miri
# Processing Record 11 of Set 5 | hailey
# Processing Record 12 of Set 5 | norsup
# Processing Record 13 of Set 5 | korla
# Processing Record 14 of Set 5 | pyapon
# Processing Record 15 of Set 5 | rantoul
# Processing Record 16 of Set 5 | khani
# Processing Record 17 of Set 5 | omsukchan
# Processing Record 18 of Set 5 | killarney
# Processing Record 19 of Set 5 | ambulu
# Processing Record 20 of Set 5 | prichard
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | mareeba
# Processing Record 24 of Set 5 | upata
# Processing Record 25 of Set 5 | panjab
# Processing Record 26 of Set 5 | fort smith
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | ostersund
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | carnarvon
# Processing Record 32 of Set 5 | kayerkan
# Processing Record 33 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 5 | black river
# Processing Record 35 of Set 5 | srednekolymsk
# Processing Record 36 of Set 5 | roma
# Processing Record 37 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | muzhi
# Processing Record 39 of Set 5 | hermanus
# Processing Record 40 of Set 5 | provideniya
# Processing Record 41 of Set 5 | bambous virieux
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | saint-francois
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | galdar
# Processing Record 47 of Set 5 | mouila
# Processing Record 48 of Set 5 | mitchell
# Processing Record 49 of Set 5 | cap malheureux
# Processing Record 50 of Set 5 | portland
# Processing Record 1 of Set 6 | sabha
# Processing Record 2 of Set 6 | grand gaube
# Processing Record 3 of Set 6 | usinsk
# Processing Record 4 of Set 6 | komsomolskiy
# Processing Record 5 of Set 6 | the valley
# Processing Record 6 of Set 6 | xai-xai
# Processing Record 7 of Set 6 | sheridan
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | waingapu
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | acapulco
# Processing Record 13 of Set 6 | douglas
# Processing Record 14 of Set 6 | ano mera
# Processing Record 15 of Set 6 | nata
# Processing Record 16 of Set 6 | shimanovsk
# Processing Record 17 of Set 6 | troitsko-pechorsk
# Processing Record 18 of Set 6 | goedereede
# Processing Record 19 of Set 6 | kushima
# Processing Record 20 of Set 6 | hasaki
# Processing Record 21 of Set 6 | yichang
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | luwuk
# Processing Record 24 of Set 6 | antofagasta
# Processing Record 25 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | sovetskiy
# Processing Record 28 of Set 6 | te anau
# Processing Record 29 of Set 6 | natal
# Processing Record 30 of Set 6 | cayenne
# Processing Record 31 of Set 6 | abilene
# Processing Record 32 of Set 6 | matagami
# Processing Record 33 of Set 6 | olafsvik
# Processing Record 34 of Set 6 | launceston
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 6 | kenai
# Processing Record 39 of Set 6 | clinton
# Processing Record 40 of Set 6 | maningrida
# Processing Record 41 of Set 6 | belyy yar
# Processing Record 42 of Set 6 | hamilton
# Processing Record 43 of Set 6 | quelimane
# Processing Record 44 of Set 6 | banjar
# Processing Record 45 of Set 6 | armidale
# Processing Record 46 of Set 6 | tilichiki
# Processing Record 47 of Set 6 | gisborne
# Processing Record 48 of Set 6 | wanaka
# Processing Record 49 of Set 6 | sept-iles
# Processing Record 50 of Set 6 | chiang khong
# Processing Record 1 of Set 7 | tambovka
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | quatre cocos
# Processing Record 5 of Set 7 | leningradskiy
# Processing Record 6 of Set 7 | dhar
# Processing Record 7 of Set 7 | nizhnevartovsk
# Processing Record 8 of Set 7 | nuuk
# Processing Record 9 of Set 7 | pak phanang
# Processing Record 10 of Set 7 | shingu
# Processing Record 11 of Set 7 | muntilan
# Processing Record 12 of Set 7 | kodinar
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | naryan-mar
# Processing Record 15 of Set 7 | dingle
# Processing Record 16 of Set 7 | cabedelo
# Processing Record 17 of Set 7 | weligama
# Processing Record 18 of Set 7 | burica
# City not found. Skipping...
# Processing Record 19 of Set 7 | tuatapere
# Processing Record 20 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 7 | amahai
# Processing Record 22 of Set 7 | port macquarie
# Processing Record 23 of Set 7 | arlit
# Processing Record 24 of Set 7 | sakakah
# Processing Record 25 of Set 7 | los llanos de aridane
# Processing Record 26 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 7 | san francisco
# Processing Record 28 of Set 7 | port antonio
# Processing Record 29 of Set 7 | viedma
# Processing Record 30 of Set 7 | palauig
# Processing Record 31 of Set 7 | puerto baquerizo moreno
# Processing Record 32 of Set 7 | kiunga
# Processing Record 33 of Set 7 | shangqiu
# Processing Record 34 of Set 7 | la uribe
# City not found. Skipping...
# Processing Record 35 of Set 7 | chokurdakh
# Processing Record 36 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 37 of Set 7 | den helder
# Processing Record 38 of Set 7 | cockburn town
# Processing Record 39 of Set 7 | omboue
# Processing Record 40 of Set 7 | lorengau
# Processing Record 41 of Set 7 | christchurch
# Processing Record 42 of Set 7 | najran
# Processing Record 43 of Set 7 | havre-saint-pierre
# Processing Record 44 of Set 7 | helong
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | daru
# Processing Record 47 of Set 7 | tarakan
# Processing Record 48 of Set 7 | igrim
# Processing Record 49 of Set 7 | seoul
# Processing Record 50 of Set 7 | berezanskaya
# Processing Record 1 of Set 8 | tuy hoa
# Processing Record 2 of Set 8 | namibe
# Processing Record 3 of Set 8 | qaqortoq
# Processing Record 4 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 8 | sinnamary
# Processing Record 6 of Set 8 | necochea
# Processing Record 7 of Set 8 | czarnkow
# Processing Record 8 of Set 8 | saint-augustin
# Processing Record 9 of Set 8 | torbat-e jam
# Processing Record 10 of Set 8 | coquimbo
# Processing Record 11 of Set 8 | sibolga
# Processing Record 12 of Set 8 | itoman
# Processing Record 13 of Set 8 | inverell
# Processing Record 14 of Set 8 | general roca
# Processing Record 15 of Set 8 | aklavik
# Processing Record 16 of Set 8 | casambalangan
# Processing Record 17 of Set 8 | atar
# Processing Record 18 of Set 8 | ye
# City not found. Skipping...
# Processing Record 19 of Set 8 | whitehorse
# Processing Record 20 of Set 8 | santa maria
# Processing Record 21 of Set 8 | rawson
# Processing Record 22 of Set 8 | antalaha
# Processing Record 23 of Set 8 | aswan
# Processing Record 24 of Set 8 | itarema
# Processing Record 25 of Set 8 | sereflikochisar
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | betare oya
# Processing Record 28 of Set 8 | skjervoy
# Processing Record 29 of Set 8 | vardo
# Processing Record 30 of Set 8 | itanhaem
# Processing Record 31 of Set 8 | taganak
# Processing Record 32 of Set 8 | araouane
# Processing Record 33 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 8 | emba
# Processing Record 35 of Set 8 | tanout
# Processing Record 36 of Set 8 | itaqui
# Processing Record 37 of Set 8 | ha tinh
# Processing Record 38 of Set 8 | effingham
# Processing Record 39 of Set 8 | kindu
# Processing Record 40 of Set 8 | tokonou
# Processing Record 41 of Set 8 | cherskiy
# Processing Record 42 of Set 8 | xunchang
# Processing Record 43 of Set 8 | yuli
# Processing Record 44 of Set 8 | fortuna
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 47 of Set 8 | mirnyy
# Processing Record 48 of Set 8 | lazaro cardenas
# Processing Record 49 of Set 8 | georgetown
# Processing Record 50 of Set 8 | andenes
# Processing Record 1 of Set 9 | vega de alatorre
# Processing Record 2 of Set 9 | farmington
# Processing Record 3 of Set 9 | tautira
# Processing Record 4 of Set 9 | mandalgovi
# Processing Record 5 of Set 9 | van buren
# Processing Record 6 of Set 9 | swan hill
# Processing Record 7 of Set 9 | ponta delgada
# Processing Record 8 of Set 9 | anadyr
# Processing Record 9 of Set 9 | pakokku
# Processing Record 10 of Set 9 | imbituba
# Processing Record 11 of Set 9 | ostrovnoy
# Processing Record 12 of Set 9 | oussouye
# Processing Record 13 of Set 9 | griffith
# Processing Record 14 of Set 9 | jeronimo monteiro
# Processing Record 15 of Set 9 | tondi
# Processing Record 16 of Set 9 | salta
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | chulman
# Processing Record 19 of Set 9 | grindavik
# Processing Record 20 of Set 9 | rae bareli
# Processing Record 21 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 9 | pisco
# Processing Record 23 of Set 9 | jardim
# Processing Record 24 of Set 9 | isaka
# Processing Record 25 of Set 9 | lensk
# Processing Record 26 of Set 9 | arcata
# Processing Record 27 of Set 9 | tsaratanana
# Processing Record 28 of Set 9 | norman wells
# Processing Record 29 of Set 9 | sisimiut
# Processing Record 30 of Set 9 | mehamn
# Processing Record 31 of Set 9 | nome
# Processing Record 32 of Set 9 | kirksville
# Processing Record 33 of Set 9 | xining
# Processing Record 34 of Set 9 | bodden town
# Processing Record 35 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 9 | kashi
# Processing Record 37 of Set 9 | tambura
# Processing Record 38 of Set 9 | basco
# Processing Record 39 of Set 9 | pouembout
# Processing Record 40 of Set 9 | terrace
# Processing Record 41 of Set 9 | rosarito
# Processing Record 42 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 9 | mizdah
# Processing Record 44 of Set 9 | sitka
# Processing Record 45 of Set 9 | martapura
# Processing Record 46 of Set 9 | palmer
# Processing Record 47 of Set 9 | nizwa
# Processing Record 48 of Set 9 | beya
# Processing Record 49 of Set 9 | maxixe
# Processing Record 50 of Set 9 | ixtapa
# Processing Record 1 of Set 10 | bo rai
# Processing Record 2 of Set 10 | shenjiamen
# Processing Record 3 of Set 10 | saint-louis
# Processing Record 4 of Set 10 | tessalit
# Processing Record 5 of Set 10 | praya
# Processing Record 6 of Set 10 | saint-leu
# Processing Record 7 of Set 10 | opuwo
# Processing Record 8 of Set 10 | gouyave
# Processing Record 9 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | vastervik
# City not found. Skipping...
# Processing Record 12 of Set 10 | xinmin
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | santa rosa
# Processing Record 15 of Set 10 | kaeo
# Processing Record 16 of Set 10 | lichinga
# Processing Record 17 of Set 10 | pascagoula
# Processing Record 18 of Set 10 | zaliztsi
# Processing Record 19 of Set 10 | valentin gomez farias
# Processing Record 20 of Set 10 | faya
# Processing Record 21 of Set 10 | pingxiang
# Processing Record 22 of Set 10 | znamenskoye
# Processing Record 23 of Set 10 | kulhudhuffushi
# Processing Record 24 of Set 10 | college
# Processing Record 25 of Set 10 | port-gentil
# Processing Record 26 of Set 10 | chegdomyn
# Processing Record 27 of Set 10 | kabare
# Processing Record 28 of Set 10 | vysokogornyy
# Processing Record 29 of Set 10 | kambove
# Processing Record 30 of Set 10 | thompson
# Processing Record 31 of Set 10 | nabire
# Processing Record 32 of Set 10 | acarau
# Processing Record 33 of Set 10 | bac lieu
# Processing Record 34 of Set 10 | bakhtiyarpur
# Processing Record 35 of Set 10 | dalvik
# Processing Record 36 of Set 10 | rocha
# Processing Record 37 of Set 10 | taltal
# Processing Record 38 of Set 10 | chernyshevskiy
# Processing Record 39 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 10 | ranau
# Processing Record 41 of Set 10 | comodoro rivadavia
# Processing Record 42 of Set 10 | ust-omchug
# Processing Record 43 of Set 10 | zhigansk
# Processing Record 44 of Set 10 | carballo
# Processing Record 45 of Set 10 | longyearbyen
# Processing Record 46 of Set 10 | kungurtug
# Processing Record 47 of Set 10 | srikakulam
# Processing Record 48 of Set 10 | wladyslawowo
# Processing Record 49 of Set 10 | pimentel
# Processing Record 50 of Set 10 | pontianak
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 11 | midland
# Processing Record 4 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 11 | paita
# Processing Record 6 of Set 11 | geraldton
# Processing Record 7 of Set 11 | saint anthony
# Processing Record 8 of Set 11 | talisay
# Processing Record 9 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 10 of Set 11 | aripuana
# Processing Record 11 of Set 11 | ukiah
# Processing Record 12 of Set 11 | lugovskiy
# City not found. Skipping...
# Processing Record 13 of Set 11 | khilok
# Processing Record 14 of Set 11 | bahia blanca
# Processing Record 15 of Set 11 | trelew
# Processing Record 16 of Set 11 | poykovskiy
# Processing Record 17 of Set 11 | lavrentiya
# Processing Record 18 of Set 11 | nelson bay
# Processing Record 19 of Set 11 | san jose
# Processing Record 20 of Set 11 | staryy nadym
# Processing Record 21 of Set 11 | sioux lookout
# Processing Record 22 of Set 11 | cochabamba
# Processing Record 23 of Set 11 | sinegorye
# Processing Record 24 of Set 11 | baglan
# Processing Record 25 of Set 11 | wahiawa
# Processing Record 26 of Set 11 | colwyn bay
# Processing Record 27 of Set 11 | sokoto
# Processing Record 28 of Set 11 | gushikawa
# Processing Record 29 of Set 11 | samarinda
# Processing Record 30 of Set 11 | staraya mayna
# Processing Record 31 of Set 11 | suntar
# Processing Record 32 of Set 11 | port moresby
# Processing Record 33 of Set 11 | corrente
# Processing Record 34 of Set 11 | stendal
# Processing Record 35 of Set 11 | santo augusto
# Processing Record 36 of Set 11 | zaysan
# Processing Record 37 of Set 11 | pitea
# Processing Record 38 of Set 11 | japura
# Processing Record 39 of Set 11 | jaciara
# Processing Record 40 of Set 11 | jiaozuo
# Processing Record 41 of Set 11 | ormara
# Processing Record 42 of Set 11 | manzil salim
# Processing Record 43 of Set 11 | nicoya
# Processing Record 44 of Set 11 | rudnyy
# Processing Record 45 of Set 11 | abnub
# Processing Record 46 of Set 11 | yakeshi
# Processing Record 47 of Set 11 | hobyo
# Processing Record 48 of Set 11 | okhotsk
# Processing Record 49 of Set 11 | porto santo
# Processing Record 50 of Set 11 | alice springs
# Processing Record 1 of Set 12 | zhuhai
# Processing Record 2 of Set 12 | constantine
# Processing Record 3 of Set 12 | vestmannaeyjar
# Processing Record 4 of Set 12 | susanville
# Processing Record 5 of Set 12 | muroto
# Processing Record 6 of Set 12 | fort nelson
# Processing Record 7 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 12 | samarai
# Processing Record 9 of Set 12 | alto vera
# City not found. Skipping...
# Processing Record 10 of Set 12 | cascais
# Processing Record 11 of Set 12 | muscat
# Processing Record 12 of Set 12 | abohar
# Processing Record 13 of Set 12 | monchegorsk
# Processing Record 14 of Set 12 | nuzvid
# Processing Record 15 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 16 of Set 12 | avera
# Processing Record 17 of Set 12 | floro
# Processing Record 18 of Set 12 | altay
# Processing Record 19 of Set 12 | fare
# Processing Record 20 of Set 12 | belmonte
# Processing Record 21 of Set 12 | tawzar
# City not found. Skipping...
# Processing Record 22 of Set 12 | tual
# Processing Record 23 of Set 12 | de-kastri
# Processing Record 24 of Set 12 | yalta
# Processing Record 25 of Set 12 | sola
# Processing Record 26 of Set 12 | muswellbrook
# Processing Record 27 of Set 12 | buluang
# Processing Record 28 of Set 12 | beloha
# Processing Record 29 of Set 12 | puerto colombia
# Processing Record 30 of Set 12 | ola
# Processing Record 31 of Set 12 | whitecourt
# Processing Record 32 of Set 12 | russell
# Processing Record 33 of Set 12 | linxia
# Processing Record 34 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 12 | pemberton
# Processing Record 36 of Set 12 | valladolid
# Processing Record 37 of Set 12 | nantucket
# Processing Record 38 of Set 12 | ascension
# Processing Record 39 of Set 12 | batouri
# Processing Record 40 of Set 12 | aasiaat
# Processing Record 41 of Set 12 | mahibadhoo
# Processing Record 42 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 12 | biltine
# Processing Record 44 of Set 12 | soyo
# Processing Record 45 of Set 12 | chimay
# Processing Record 46 of Set 12 | buraydah
# Processing Record 47 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 12 | gimli
# Processing Record 49 of Set 12 | port hawkesbury
# Processing Record 50 of Set 12 | tazovskiy
# Processing Record 1 of Set 13 | canavieiras
# Processing Record 2 of Set 13 | zinder
# Processing Record 3 of Set 13 | dorobantu
# Processing Record 4 of Set 13 | constitucion
# Processing Record 5 of Set 13 | nazret
# Processing Record 6 of Set 13 | gazanjyk
# Processing Record 7 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 13 | wajima
# Processing Record 9 of Set 13 | prieska
# Processing Record 10 of Set 13 | carutapera
# Processing Record 11 of Set 13 | altamont
# Processing Record 12 of Set 13 | batie
# Processing Record 13 of Set 13 | nouadhibou
# Processing Record 14 of Set 13 | tabuk
# Processing Record 15 of Set 13 | vallenar
# Processing Record 16 of Set 13 | washington
# Processing Record 17 of Set 13 | fairbanks
# Processing Record 18 of Set 13 | praia da vitoria
# Processing Record 19 of Set 13 | mpika
# Processing Record 20 of Set 13 | gat
# Processing Record 21 of Set 13 | warrington
# Processing Record 22 of Set 13 | san luis
# Processing Record 23 of Set 13 | noumea
# Processing Record 24 of Set 13 | along
# Processing Record 25 of Set 13 | svetlogorsk
# Processing Record 26 of Set 13 | goba
# Processing Record 27 of Set 13 | webb city
# Processing Record 28 of Set 13 | kysyl-syr
# Processing Record 29 of Set 13 | colomi
# Processing Record 30 of Set 13 | kamiiso
# Processing Record 31 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 32 of Set 13 | holoby
# Processing Record 33 of Set 13 | atambua
# Processing Record 34 of Set 13 | anda
# Processing Record 35 of Set 13 | chama
# Processing Record 36 of Set 13 | sampit
# Processing Record 37 of Set 13 | coihaique
# Processing Record 38 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 13 | yamethin
# Processing Record 40 of Set 13 | bam
# Processing Record 41 of Set 13 | neiafu
# Processing Record 42 of Set 13 | rawlins
# Processing Record 43 of Set 13 | abu kamal
# Processing Record 44 of Set 13 | shangrao
# Processing Record 45 of Set 13 | setermoen
# Processing Record 46 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 13 | amparafaravola
# Processing Record 48 of Set 13 | sobolevo
# Processing Record 49 of Set 13 | pajapan
# Processing Record 50 of Set 13 | barra do corda
# Processing Record 1 of Set 14 | nouakchott
# Processing Record 2 of Set 14 | kalmunai
# Processing Record 3 of Set 14 | lososina
# Processing Record 4 of Set 14 | camacha
# Processing Record 5 of Set 14 | baie-comeau
# Processing Record 6 of Set 14 | inirida
# Processing Record 7 of Set 14 | katobu
# Processing Record 8 of Set 14 | ahipara
# Processing Record 9 of Set 14 | blue springs
# Processing Record 10 of Set 14 | kabalo
# Processing Record 11 of Set 14 | mayo
# Processing Record 12 of Set 14 | sorong
# Processing Record 13 of Set 14 | lucea
# Processing Record 14 of Set 14 | northam
# Processing Record 15 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 14 | nakamura
# Processing Record 17 of Set 14 | havelock
# Processing Record 18 of Set 14 | vidim
# Processing Record 19 of Set 14 | hamada
# Processing Record 20 of Set 14 | abu samrah
# Processing Record 21 of Set 14 | dakar
# Processing Record 22 of Set 14 | hagondange
# Processing Record 23 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 24 of Set 14 | sao joao da barra
# Processing Record 25 of Set 14 | broken hill
# Processing Record 26 of Set 14 | san vicente
# Processing Record 27 of Set 14 | uruzgan
# Processing Record 28 of Set 14 | maniitsoq
# Processing Record 29 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 14 | nyurba
# Processing Record 31 of Set 14 | flin flon
# Processing Record 32 of Set 14 | hofn
# Processing Record 33 of Set 14 | mayenne
# Processing Record 34 of Set 14 | koumac
# Processing Record 35 of Set 14 | urla
# Processing Record 36 of Set 14 | tarko-sale
# Processing Record 37 of Set 14 | ballina
# Processing Record 38 of Set 14 | kilindoni
# Processing Record 39 of Set 14 | gladstone
# Processing Record 40 of Set 14 | talcahuano
# Processing Record 41 of Set 14 | rakitnoye
# Processing Record 42 of Set 14 | vilhena
# Processing Record 43 of Set 14 | diffa
# Processing Record 44 of Set 14 | katherine
# Processing Record 45 of Set 14 | marawi
# Processing Record 46 of Set 14 | nkowakowa
# Processing Record 47 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 14 | jambi
# Processing Record 49 of Set 14 | vostok
# Processing Record 50 of Set 14 | save
# Processing Record 1 of Set 15 | galveston
# Processing Record 2 of Set 15 | awbari
# Processing Record 3 of Set 15 | binghamton
# Processing Record 4 of Set 15 | tucupita
# Processing Record 5 of Set 15 | erdenet
# Processing Record 6 of Set 15 | santa quiteria
# Processing Record 7 of Set 15 | bambanglipuro
# Processing Record 8 of Set 15 | inuvik
# Processing Record 9 of Set 15 | machinga
# Processing Record 10 of Set 15 | changji
# Processing Record 11 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 12 of Set 15 | qinhuangdao
# Processing Record 13 of Set 15 | petrozavodsk
# Processing Record 14 of Set 15 | nea vissa
# Processing Record 15 of Set 15 | orhei
# Processing Record 16 of Set 15 | oranjestad
# Processing Record 17 of Set 15 | les cayes
# Processing Record 18 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 19 of Set 15 | arawa
# Processing Record 20 of Set 15 | calvinia
# Processing Record 21 of Set 15 | leh
# Processing Record 22 of Set 15 | florianopolis
# Processing Record 23 of Set 15 | reconquista
# Processing Record 24 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 25 of Set 15 | strezhevoy
# Processing Record 26 of Set 15 | wamba
# Processing Record 27 of Set 15 | wonopringgo
# Processing Record 28 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 15 | gizo
# Processing Record 30 of Set 15 | mtwara
# Processing Record 31 of Set 15 | statesboro
# Processing Record 32 of Set 15 | lokoja
# Processing Record 33 of Set 15 | bougouni
# Processing Record 34 of Set 15 | khuzhir
# Processing Record 35 of Set 15 | zeya
# Processing Record 36 of Set 15 | mweka
# Processing Record 37 of Set 15 | hanna
# Processing Record 38 of Set 15 | luau
# Processing Record 39 of Set 15 | usogorsk
# Processing Record 40 of Set 15 | pochutla
# Processing Record 41 of Set 15 | qiongshan
# Processing Record 42 of Set 15 | padang
# Processing Record 43 of Set 15 | baykit
# Processing Record 44 of Set 15 | plettenberg bay
# Processing Record 45 of Set 15 | lebu
# Processing Record 46 of Set 15 | dourbali
# Processing Record 47 of Set 15 | kewanee
# Processing Record 48 of Set 15 | san
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     74.55        96          21
# 1   Pangnirtung  66.1451  -65.7125    -19.23        91          71
# 2      Westport  41.1415  -73.3579     46.89        91         100
# 3         Isiro   2.7739   27.6160     65.73        55          75
# 4   Porto Velho  -8.7619  -63.9039     71.65        94          20
# 5          Hilo  19.7297 -155.0900     82.27        70          20
# 6      Tasiilaq  65.6145  -37.6368     12.36        95         100
# 7  Punta Arenas -53.1500  -70.9167     57.31        82           0
# 8       Labuhan  -6.8844  112.2051     84.70        68          98
# 9  Kruisfontein -34.0033   24.7314     65.88        94           0
#
#    Wind Speed Country   Current Description
# 0        6.08      EC            few clouds
# 1        5.86      CA         broken clouds
# 2       14.97      US  heavy intensity rain
# 3        1.66      CD         broken clouds
# 4        2.30      BR            light rain
# 5       12.66      US            few clouds
# 6        5.37      GL            light snow
# 7       14.97      CL             clear sky
# 8        2.95      ID       overcast clouds
# 9        3.78      ZA             clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country","Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     74.55        96          21
# 1   Pangnirtung      CA  66.1451  -65.7125    -19.23        91          71
# 2      Westport      US  41.1415  -73.3579     46.89        91         100
# 3         Isiro      CD   2.7739   27.6160     65.73        55          75
# 4   Porto Velho      BR  -8.7619  -63.9039     71.65        94          20
# 5          Hilo      US  19.7297 -155.0900     82.27        70          20
# 6      Tasiilaq      GL  65.6145  -37.6368     12.36        95         100
# 7  Punta Arenas      CL -53.1500  -70.9167     57.31        82           0
# 8       Labuhan      ID  -6.8844  112.2051     84.70        68          98
# 9  Kruisfontein      ZA -34.0033   24.7314     65.88        94           0
#
#    Wind Speed   Current Description
# 0        6.08            few clouds
# 1        5.86         broken clouds
# 2       14.97  heavy intensity rain
# 3        1.66         broken clouds
# 4        2.30            light rain
# 5       12.66            few clouds
# 6        5.37            light snow
# 7       14.97             clear sky
# 8        2.95       overcast clouds
# 9        3.78             clear sky

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
